# %%
import requests
import re
import pandas as pd
from bs4 import BeautifulSoup

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
resultados_imagenes = {"campeon": [],
                        "portada":[], 
                        "fondo": [], 
                       "pasiva": [],
                        "Q": [], 
                         "W": [], 
                        "E": [],
                       "R": []}

# %%
lista_campeones = ['Aatrox',
 'Ahri',
 'Akali',
 'Alistar',
 'Amumu',
 'Anivia',
 'Annie',
 'Ashe',
 'Aurelion Sol',
 'Azir',
 'Bard',
 'Blitzcrank',
 'Brand',
 'Braum',
 'Caitlyn',
 'Camille',
 'Cassiopeia',
 "Cho'Gath",
 'Corki',
 'Darius',
 'Diana',
 'Dr. Mundo',
 'Draven',
 'Ekko',
 'Elise',
 'Evelynn',
 'Ezreal',
 'Fiddlesticks',
 'Fiora',
 'Fizz',
 'Galio',
 'Gangplank',
 'Garen',
 'Gnar',
 'Gragas',
 'Graves',
 'Hecarim',
 'Heimerdinger',
 'Illaoi',
 'Irelia',
 'Ivern',
 'Janna',
 'Jarvan IV',
 'Jax',
 'Jayce',
 'Jhin',
 'Jinx',
 "Kai'Sa",
 'Kalista',
 'Karma',
 'Karthus',
 'Kassadin',
 'Katarina',
 'Kayle',
 'Kayn',
 'Kennen',
 "Kha'Zix",
 'Kindred',
 'Kled',
 "Kog'Maw",
 'LeBlanc',
 'Lee Sin',
 'Leona',
 'Lissandra',
 'Lucian',
 'Lulu',
 'Lux',
 'Malphite',
 'Malzahar',
 'Maokai',
 'Master Yi',
 'Miss Fortune',
 'Mordekaiser',
 'Morgana',
 'Nami',
 'Nasus',
 'Nautilus',
 'Neeko',
 'Nidalee',
 'Nocturne',
 'Nunu & Willump',
 'Olaf',
 'Orianna',
 'Ornn',
 'Pantheon',
 'Poppy',
 'Pyke',
 'Qiyana',
 'Quinn',
 'Rakan',
 'Rammus',
 "Rek'Sai",
 'Renekton',
 'Rengar',
 'Riven',
 'Rumble',
 'Ryze',
 'Sejuani',
 'Senna',
 'Shaco',
 'Shen',
 'Shyvana',
 'Singed',
 'Sion',
 'Sivir',
 'Skarner',
 'Sona',
 'Soraka',
 'Swain',
 'Sylas',
 'Syndra',
 'Tahm Kench',
 'Taliyah',
 'Talon',
 'Taric',
 'Teemo',
 'Thresh',
 'Tristana',
 'Trundle',
 'Tryndamere',
 'Twisted Fate',
 'Twitch',
 'Udyr',
 'Urgot',
 'Varus',
 'Vayne',
 'Veigar',
 "Vel'Koz",
 'Vi',
 'Viktor',
 'Vladimir',
 'Volibear',
 'Warwick',
 'Wukong',
 'Xayah',
 'Xerath',
 'Xin Zhao',
 'Yasuo',
 'Yorick',
 'Yuumi',
 'Zac',
 'Zed',
 'Ziggs',
 'Zilean',
 'Zoe',
 'Zyra']

# %%
champs_minusculas = []

# %%
for i in lista_campeones:
  champs_minusculas.append(i.lower())

# %%
champs_minusculas
# Out:
# ['aatrox',
#  'ahri',
#  'akali',
#  'alistar',
#  'amumu',
#  'anivia',
#  'annie',
#  'ashe',
#  'aurelion sol',
#  'azir',
#  'bard',
#  'blitzcrank',
#  'brand',
#  'braum',
#  'caitlyn',
#  'camille',
#  'cassiopeia',
#  "cho'gath",
#  'corki',
#  'darius',
#  'diana',
#  'dr. mundo',
#  'draven',
#  'ekko',
#  'elise',
#  'evelynn',
#  'ezreal',
#  'fiddlesticks',
#  'fiora',
#  'fizz',
#  'galio',
#  'gangplank',
#  'garen',
#  'gnar',
#  'gragas',
#  'graves',
#  'hecarim',
#  'heimerdinger',
#  'illaoi',
#  'irelia',
#  'ivern',
#  'janna',
#  'jarvan iv',
#  'jax',
#  'jayce',
#  'jhin',
#  'jinx',
#  "kai'sa",
#  'kalista',
#  'karma',
#  'karthus',
#  'kassadin',
#  'katarina',
#  'kayle',
#  'kayn',
#  'kennen',
#  "kha'zix",
#  'kindred',
#  'kled',
#  "kog'maw",
#  'leblanc',
#  'lee sin',
#  'leona',
#  'lissandra',
#  'lucian',
#  'lulu',
#  'lux',
#  'malphite',
#  'malzahar',
#  'maokai',
#  'master yi',
#  'miss fortune',
#  'mordekaiser',
#  'morgana',
# ...

# %%
lista_def = []

# %%
for i in champs_minusculas:
  i2 = i.replace("'", "-")
  i3 = i2.replace(".", "")
  i4 = i3.replace(" ", "-")

  lista_def.append(i4)

# %%
lista_def[80] = lista_def[80].replace("nunu-&-willump", "nunu")

# %%
lista_def[80]
# Out:
# 'nunu'

# %%
lista_def
# Out:
# ['aatrox',
#  'ahri',
#  'akali',
#  'alistar',
#  'amumu',
#  'anivia',
#  'annie',
#  'ashe',
#  'aurelion-sol',
#  'azir',
#  'bard',
#  'blitzcrank',
#  'brand',
#  'braum',
#  'caitlyn',
#  'camille',
#  'cassiopeia',
#  'cho-gath',
#  'corki',
#  'darius',
#  'diana',
#  'dr-mundo',
#  'draven',
#  'ekko',
#  'elise',
#  'evelynn',
#  'ezreal',
#  'fiddlesticks',
#  'fiora',
#  'fizz',
#  'galio',
#  'gangplank',
#  'garen',
#  'gnar',
#  'gragas',
#  'graves',
#  'hecarim',
#  'heimerdinger',
#  'illaoi',
#  'irelia',
#  'ivern',
#  'janna',
#  'jarvan-iv',
#  'jax',
#  'jayce',
#  'jhin',
#  'jinx',
#  'kai-sa',
#  'kalista',
#  'karma',
#  'karthus',
#  'kassadin',
#  'katarina',
#  'kayle',
#  'kayn',
#  'kennen',
#  'kha-zix',
#  'kindred',
#  'kled',
#  'kog-maw',
#  'leblanc',
#  'lee-sin',
#  'leona',
#  'lissandra',
#  'lucian',
#  'lulu',
#  'lux',
#  'malphite',
#  'malzahar',
#  'maokai',
#  'master-yi',
#  'miss-fortune',
#  'mordekaiser',
#  'morgana',
#  'nami',
# ...

# %%
lista_imagenes1 = []

# %%
def imagenes_url (lista)  
  
  for i in lista:

    url = "https://www.leagueoflegends.com/es-es/champions/"+ f"{i}"
    page = requests.get(url)

  
    if page.status_code == 200:
        sopa = BeautifulSoup(page.content, 'html.parser')
        lista_imagenes1.append(sopa.find_all("img"))

# %%
imagenes_url (lista_campeones)

# %%
def limpieza_fondo (lista)

  for i in lista:
    i1 = str(i[0]).replace('<img alt="" class="style__NoScriptImg-g183su-0 style__Img-g183su-1 cipsic dBitJH" src="', (""))
    i2 = i1.replace('" style="object-fit:cover;object-position:center 20%"/>', (""))
    resultados_imagenes["fondo"].append(i2)

# %%
limpieza_fondo (lista_imagenes1)

# %%
def limpieza_pasiva (lista)

  for i in lista:
    i1 = str(i[4]).replace('<img alt="" class="style__NoScriptImg-g183su-0 style__Img-g183su-1 cipsic dBitJH" src="', (""))
    i2 = i1.replace('"/>', (""))
    resultados_imagenes["pasiva"].append(i2)

# %%
limpieza_pasiva (lista_imagenes1)

# %%
def limpieza_habilidades (lista, habilidad)  
  
  for i in lista_imagenes1:
    i1 = str(i[6]).replace('<img alt="" class="style__NoScriptImg-g183su-0 style__Img-g183su-1 cipsic dBitJH" src="', (""))
    i2 = i1.replace('"/>', (""))
    resultados_imagenes[f"{habilidad}"].append(i2)

# %%
limpieza_habilidades (lista_imagenes1, Q)

# %%
limpieza_habilidades (lista_imagenes1, W)

# %%
limpieza_habilidades (lista_imagenes1, E)

# %%
limpieza_habilidades (lista_imagenes1, R)

# %%
for i in lista_campeones:
  resultados_imagenes["campeon"].append(i)

# %%
page1 = requests.get("https://app.mobalytics.gg/lol/champions")

# %%
page1.status_code
# Out:
# 200

# %%
sopa2 = BeautifulSoup(page1.content, 'html.parser')

# %%
lista_imagenes2 = []

# %%
lista_imagenes2.append(sopa2.find_all("img", {"class" : "m-0"}))

# %%
lista_imagenes2[0][1].get("src")
# Out:
# 'https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/ahri.png'

# %%
len(lista_imagenes2[0])
# Out:
# 160

# %%
lista_temp = []

# %%
def limpieza_portada(lista)

  for i in lista[0]:
    i1 = str(i).replace('<img alt="" class="m-0" loading="lazy" src="', (""))
    i2 = i1.replace('"/>', (""))
    lista_temp.append(i2)

# %%
limpieza_portada(lista_imagenes2)

# %%
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/belveth.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/lillia.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/rell.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/renata.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/samira.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/sett.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/vex.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/viego.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/yone.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/zeri.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/akshan.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/aphelios.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/gwen.png")
lista_temp.remove("https://cdn.mobalytics.gg/assets/lol/images/dd/champions/icons/seraphine.png")

# %%
len(lista_temp)
# Out:
# 146

# %%
for i in lista_temp:
  resultados_imagenes["portada"].append(i)

# %%
resultados_imagenes
# Out:
# {'E': ['https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AatroxE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AhriSeduce.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AkaliE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AlistarE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/Tantrum.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/Frostbite.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AnnieE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AsheSpiritOfTheHawk.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AurelionSolE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/AzirEWrapper.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/BardE.png',
#   'https://ddragon.leagueoflegends.com/cdn/12.11.1/img/spell/PowerFist.png',
# ...

# %%
len(resultados_imagenes["fondo"])
# Out:
# 146

# %%
images = pd.DataFrame.from_dict(resultados_imagenes)

# %%
images.to_csv("images.csv")

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-471805cc-54be-4a0b-80d6-6fdb387c5f3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-471805cc-54be-4a0b-80d6-6fdb387c5f3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving champions.csv to champions.csv

# %%
from google.colab import files
files.download("images.csv")

# %%
campeones = pd.read_csv("champions.csv")

# %%
campeones
# Out:
#    Unnamed: 0    name  Incremento HP Total HP  Incremento Magic Power  \
# 0           0  Aatrox         1530.0   2110,0                     0.0
# 1           1    Ahri         1564.0   2090,0                   425.0
#
#   Total Magic Power  Incremento Attack Damage  Incremento Attack Speed  \
# 0               0,0                      85.0                     42.5
# 1             843,0                      51.0                     34.0
#
#    Incremento Attack Resistance Total Attack Damage  ...               Pasiva  \
# 0                         55.25               145,0  ...  Deathbringer Stance
# 1                         59.50              104,04  ...        Essence Theft
#
#   Posicion          Play Rate TOP Play Rate Jungle Play Rate MID Play Rate  \
# 0      TOP  6,776554184306237      6.409202         0.018245      0.349107
# 1      MID  4,652497366770692      0.016624         0.000000      4.514049
#
#    ADC Play Rate  Support Play Rate  \
# ...

# %%
campeones = campeones.drop(["Unnamed: 0"], axis=1)

# %%
ids = campeones["ID"].tolist

# %%
letsgo = pd.merge(campeones, images, left_on= "name", right_on= "campeon")

letsgo = letsgo.drop(["campeon"], axis=1)

letsgo
# Out:
#      Unnamed: 0     name  Incremento HP  Total HP  Incremento Magic Power  \
# 0             0   Aatrox         1530.0   2110.00                     0.0
# 1             1     Ahri         1564.0   2090.00                   425.0
# 2             2    Akali         1615.0   2190.00                     0.0
# 3             3  Alistar         1802.0   2375.36                   680.0
# 4             4    Amumu         1428.0   2041.12                   680.0
# ..          ...      ...            ...       ...                     ...
# 141         141      Zed         1445.0   2029.00                     0.0
# 142         142    Ziggs         1564.0   2100.00                   399.5
# 143         143   Zilean         1394.0   1898.00                   510.0
# 144         144      Zoe         1564.0   2124.00                   425.0
# 145         145     Zyra         1343.0   1847.00                   425.0
#
#      Total Magic Power  Incremento Attack Damage  Incremento Attack Speed  \
# ...

# %%
letsgo = letsgo.drop(["Unnamed: 0"], axis=1)

# %%
letsgo.head(2)
# Out:
#      name  Incremento HP  Total HP  Incremento Magic Power  Total Magic Power  \
# 0  Aatrox         1530.0    2110.0                     0.0                0.0
# 1    Ahri         1564.0    2090.0                   425.0              843.0
#
#    Incremento Attack Damage  Incremento Attack Speed  \
# 0                      85.0                     42.5
# 1                      51.0                     34.0
#
#    Incremento Attack Resistance  Total Attack Damage  \
# 0                         55.25               145.00
# 1                         59.50               104.04
#
#    Incremento Magic Resistance  ...  MID Play Rate  ADC Play Rate  \
# 0                        21.25  ...       0.349107       0.000000
# 1                         8.50  ...       4.514049       0.006099
#
#    Support Play Rate                                            portada  \
# 0           0.000000  https://cdn.mobalytics.gg/assets/lol/images/dd...
# ...

# %%
letsgo.to_csv("champsdef.csv")

# %%
from google.colab import files
files.download("champsdef.csv")
